# %% [markdown]
# # LIS 501 Text Mining: Week 02 -- Basics of Text Preprocessing
#
# This notebook guides you through a real application of Spacy and Nltk to study text preprocessing.

# %% [markdown]
# ## Text Preprocess

# %%
# make sure the required python packages are installed

# install nltk (we'll use 3.9.1 in Spring '26)
# %pip install nltk==3.9.1 --upgrade

# install spacy (we'll use 3.8.4 in Spring '26)
# %pip install spacy==3.8.4 --upgrade
# Out:
# Collecting nltk==3.9.1
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting click (from nltk==3.9.1)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting joblib (from nltk==3.9.1)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting regex>=2021.8.3 (from nltk==3.9.1)
#   Downloading regex-2026.1.15-cp310-cp310-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting tqdm (from nltk==3.9.1)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 34.0 MB/s  0:00:00
# Downloading regex-2026.1.15-cp310-cp310-macosx_11_0_arm64.whl (288 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, joblib, click, nltk
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [nltk]━━━━━━ 4/5 [nltk]b]
# Successfully installed click-8.3.1 joblib-1.5.3 nltk-3.9.1 regex-2026.1.15 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.
# Collecting spacy==3.8.4
#   Downloading spacy-3.8.4-cp310-cp310-macosx_11_0_arm64.whl.metadata (27 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy==3.8.4)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy==3.8.4)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy==3.8.4)
#   Downloading murmurhash-1.0.15-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy==3.8.4)
#   Downloading cymem-2.0.13-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.7 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy==3.8.4)
#   Downloading preshed-3.0.12-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.5 kB)
# Collecting thinc<8.4.0,>=8.3.4 (from spacy==3.8.4)
#   Downloading thinc-8.3.10-cp310-cp310-macosx_11_0_arm64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy==3.8.4)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy==3.8.4)
#   Downloading srsly-2.5.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy==3.8.4)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.1.0 (from spacy==3.8.4)
#   Downloading weasel-0.4.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy==3.8.4)
#   Downloading typer-0.21.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/mjiang228/miniconda3/envs/lis501/lib/python3.10/site-packages (from spacy==3.8.4) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /Users/mjiang228/miniconda3/envs/lis501/lib/python3.10/site-packages (from spacy==3.8.4) (2.2.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/mjiang228/miniconda3/envs/lis501/lib/python3.10/site-packages (from spacy==3.8.4) (2.32.5)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from spacy==3.8.4)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Requirement already satisfied: jinja2 in /Users/mjiang228/miniconda3/envs/lis501/lib/python3.10/site-packages (from spacy==3.8.4) (3.1.6)
# Requirement already satisfied: setuptools in /Users/mjiang228/miniconda3/envs/lis501/lib/python3.10/site-packages (from spacy==3.8.4) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in /Users/mjiang228/miniconda3/envs/lis501/lib/python3.10/site-packages (from spacy==3.8.4) (25.0)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy==3.8.4)
#   Downloading langcodes-3.5.1-py3-none-any.whl.metadata (30 kB)
# Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.8.4)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.8.4)
#   Downloading pydantic_core-2.41.5-cp310-cp310-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/mjiang228/miniconda3/envs/lis501/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.8.4) (4.15.0)
# Collecting typing-inspection>=0.4.2 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.8.4)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/mjiang228/miniconda3/envs/lis501/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.8.4) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mjiang228/miniconda3/envs/lis501/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.8.4) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mjiang228/miniconda3/envs/lis501/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.8.4) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mjiang228/miniconda3/envs/lis501/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.8.4) (2026.1.4)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.4->spacy==3.8.4)
#   Downloading blis-1.3.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (7.5 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.4->spacy==3.8.4)
#   Downloading confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: click>=8.0.0 in /Users/mjiang228/miniconda3/envs/lis501/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy==3.8.4) (8.3.1)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy==3.8.4)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer<1.0.0,>=0.3.0->spacy==3.8.4)
#   Downloading rich-14.3.1-py3-none-any.whl.metadata (18 kB)
# Collecting typer-slim<1.0.0,>=0.3.0 (from weasel<0.5.0,>=0.1.0->spacy==3.8.4)
#   Downloading typer_slim-0.21.1-py3-none-any.whl.metadata (16 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.1.0->spacy==3.8.4)
#   Downloading cloudpathlib-0.23.0-py3-none-any.whl.metadata (16 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.1.0->spacy==3.8.4)
#   Downloading smart_open-7.5.0-py3-none-any.whl.metadata (24 kB)
# Collecting wrapt (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy==3.8.4)
#   Downloading wrapt-2.0.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.0 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy==3.8.4)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/mjiang228/miniconda3/envs/lis501/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy==3.8.4) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy==3.8.4)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/mjiang228/miniconda3/envs/lis501/lib/python3.10/site-packages (from jinja2->spacy==3.8.4) (3.0.3)
# Downloading spacy-3.8.4-cp310-cp310-macosx_11_0_arm64.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 29.7 MB/s  0:00:00 eta 0:00:01
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.13-cp310-cp310-macosx_11_0_arm64.whl (43 kB)
# Downloading langcodes-3.5.1-py3-none-any.whl (183 kB)
# Downloading murmurhash-1.0.15-cp310-cp310-macosx_11_0_arm64.whl (27 kB)
# Downloading preshed-3.0.12-cp310-cp310-macosx_11_0_arm64.whl (124 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp310-cp310-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 40.6 MB/s  0:00:00
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.2-cp310-cp310-macosx_11_0_arm64.whl (653 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 653.4/653.4 kB 28.9 MB/s  0:00:00
# Downloading thinc-8.3.10-cp310-cp310-macosx_11_0_arm64.whl (772 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.3/772.3 kB 36.7 MB/s  0:00:00
# Downloading blis-1.3.3-cp310-cp310-macosx_11_0_arm64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 55.2 MB/s  0:00:00
# Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading typer-0.21.1-py3-none-any.whl (47 kB)
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-0.4.3-py3-none-any.whl (50 kB)
# Downloading cloudpathlib-0.23.0-py3-none-any.whl (62 kB)
# Downloading smart_open-7.5.0-py3-none-any.whl (63 kB)
# Downloading typer_slim-0.21.1-py3-none-any.whl (47 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading rich-14.3.1-py3-none-any.whl (309 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading wrapt-2.0.1-cp310-cp310-macosx_11_0_arm64.whl (61 kB)
# Installing collected packages: wrapt, wasabi, typing-inspection, typer-slim, spacy-loggers, spacy-legacy, shellingham, pydantic-core, murmurhash, mdurl, langcodes, cymem, cloudpathlib, catalogue, blis, annotated-types, srsly, smart-open, pydantic, preshed, markdown-it-py, rich, confection, weasel, typer, thinc, spacy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27/27 [spacy]38;5;237m━ 26/27 [spacy]wn-it-py]
# Successfully installed annotated-types-0.7.0 blis-1.3.3 catalogue-2.0.10 cloudpathlib-0.23.0 confection-0.1.5 cymem-2.0.13 langcodes-3.5.1 markdown-it-py-4.0.0 mdurl-0.1.2 murmurhash-1.0.15 preshed-3.0.12 pydantic-2.12.5 pydantic-core-2.41.5 rich-14.3.1 shellingham-1.5.4 smart-open-7.5.0 spacy-3.8.4 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.2 thinc-8.3.10 typer-0.21.1 typer-slim-0.21.1 typing-inspection-0.4.2 wasabi-1.1.3 weasel-0.4.3 wrapt-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# download the spacy en_core_web_sm model (3.8.0 version in Spring 2026)
# !python -m spacy download en_core_web_sm-3.8.0 --direct
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 55.9 MB/s  0:00:00 63.3 MB/s eta 0:00:01
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
import en_core_web_sm

nlp = en_core_web_sm.load()

# %%
import nltk
nltk.download('popular')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/mjiang228/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /Users/mjiang228/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /Users/mjiang228/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /Users/mjiang228/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /Users/mjiang228/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /Users/mjiang228/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /Users/mjiang228/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /Users/mjiang228/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /Users/mjiang228/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /Users/mjiang228/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /Users/mjiang228/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     /Users/mjiang228/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     /Users/mjiang228/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /Users/mjiang228/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     /Users/mjiang228/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     /Users/mjiang228/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /Users/mjiang228/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /Users/mjiang228/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /Users/mjiang228/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /Users/mjiang228/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /Users/mjiang228/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/mjiang228/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %%
text = "Text mining, text data mining (TDM) or text analytics is the process of deriving high-quality information from text. It involves the discovery by computer of new, previously unknown information, by automatically extracting information from different written resources.[1] Written resources may include websites, books, emails, reviews, and articles.[2] High-quality information is typically obtained by devising patterns and trends by means such as statistical pattern learning. According to Hotho et al. (2005), there are three perspectives of text mining: information extraction, data mining, and knowledge discovery in databases (KDD).[3] Text mining usually involves the process of structuring the input text (usually parsing, along with the addition of some derived linguistic features and the removal of others, and subsequent insertion into a database), deriving patterns within the structured data, and finally evaluation and interpretation of the output. 'High quality' in text mining usually refers to some combination of relevance, novelty, and interest. Typical text mining tasks include text categorization, text clustering, concept/entity extraction, production of granular taxonomies, sentiment analysis, document summarization, and entity relation modeling (i.e., learning relations between named entities)."
text
# Out:
# "Text mining, text data mining (TDM) or text analytics is the process of deriving high-quality information from text. It involves the discovery by computer of new, previously unknown information, by automatically extracting information from different written resources.[1] Written resources may include websites, books, emails, reviews, and articles.[2] High-quality information is typically obtained by devising patterns and trends by means such as statistical pattern learning. According to Hotho et al. (2005), there are three perspectives of text mining: information extraction, data mining, and knowledge discovery in databases (KDD).[3] Text mining usually involves the process of structuring the input text (usually parsing, along with the addition of some derived linguistic features and the removal of others, and subsequent insertion into a database), deriving patterns within the structured data, and finally evaluation and interpretation of the output. 'High quality' in text mining usually refers to some combination of relevance, novelty, and interest. Typical text mining tasks include text categorization, text clustering, concept/entity extraction, production of granular taxonomies, sentiment analysis, document summarization, and entity relation modeling (i.e., learning relations between named entities)."

# %% [markdown]
# ## Use NLTK for Text Preprocessing
#
# #### Sentence Segmentation

# %%
from nltk.tokenize import sent_tokenize

nltk_sentences = sent_tokenize(text)
print("Number of sentences: ", len(nltk_sentences))
print("\n")

for s in nltk_sentences:
    print (s)
# Out:
# Number of sentences:  9
#
#
# Text mining, text data mining (TDM) or text analytics is the process of deriving high-quality information from text.
# It involves the discovery by computer of new, previously unknown information, by automatically extracting information from different written resources.
# [1] Written resources may include websites, books, emails, reviews, and articles.
# [2] High-quality information is typically obtained by devising patterns and trends by means such as statistical pattern learning.
# According to Hotho et al.
# (2005), there are three perspectives of text mining: information extraction, data mining, and knowledge discovery in databases (KDD).
# [3] Text mining usually involves the process of structuring the input text (usually parsing, along with the addition of some derived linguistic features and the removal of others, and subsequent insertion into a database), deriving patterns within the structured data, and finally evaluation and interpretation of the output.
# 'High quality' in text mining usually refers to some combination of relevance, novelty, and interest.
# Typical text mining tasks include text categorization, text clustering, concept/entity extraction, production of granular taxonomies, sentiment analysis, document summarization, and entity relation modeling (i.e., learning relations between named entities).

# %% [markdown]
# #### Tokenization

# %%
from nltk.tokenize import word_tokenize

nltk_words = word_tokenize(text)
print(nltk_words)
# Out:
# ['Text', 'mining', ',', 'text', 'data', 'mining', '(', 'TDM', ')', 'or', 'text', 'analytics', 'is', 'the', 'process', 'of', 'deriving', 'high-quality', 'information', 'from', 'text', '.', 'It', 'involves', 'the', 'discovery', 'by', 'computer', 'of', 'new', ',', 'previously', 'unknown', 'information', ',', 'by', 'automatically', 'extracting', 'information', 'from', 'different', 'written', 'resources', '.', '[', '1', ']', 'Written', 'resources', 'may', 'include', 'websites', ',', 'books', ',', 'emails', ',', 'reviews', ',', 'and', 'articles', '.', '[', '2', ']', 'High-quality', 'information', 'is', 'typically', 'obtained', 'by', 'devising', 'patterns', 'and', 'trends', 'by', 'means', 'such', 'as', 'statistical', 'pattern', 'learning', '.', 'According', 'to', 'Hotho', 'et', 'al', '.', '(', '2005', ')', ',', 'there', 'are', 'three', 'perspectives', 'of', 'text', 'mining', ':', 'information', 'extraction', ',', 'data', 'mining', ',', 'and', 'knowledge', 'discovery', 'in', 'databases', '(', 'KDD', ')', '.', '[', '3', ']', 'Text', 'mining', 'usually', 'involves', 'the', 'process', 'of', 'structuring', 'the', 'input', 'text', '(', 'usually', 'parsing', ',', 'along', 'with', 'the', 'addition', 'of', 'some', 'derived', 'linguistic', 'features', 'and', 'the', 'removal', 'of', 'others', ',', 'and', 'subsequent', 'insertion', 'into', 'a', 'database', ')', ',', 'deriving', 'patterns', 'within', 'the', 'structured', 'data', ',', 'and', 'finally', 'evaluation', 'and', 'interpretation', 'of', 'the', 'output', '.', "'High", 'quality', "'", 'in', 'text', 'mining', 'usually', 'refers', 'to', 'some', 'combination', 'of', 'relevance', ',', 'novelty', ',', 'and', 'interest', '.', 'Typical', 'text', 'mining', 'tasks', 'include', 'text', 'categorization', ',', 'text', 'clustering', ',', 'concept/entity', 'extraction', ',', 'production', 'of', 'granular', 'taxonomies', ',', 'sentiment', 'analysis', ',', 'document', 'summarization', ',', 'and', 'entity', 'relation', 'modeling', '(', 'i.e.', ',', 'learning', 'relations', 'between', 'named', 'entities', ')', '.']
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %% [markdown]
# #### Case Normalization

# %%
lowercase_text = text.lower()
print(lowercase_text)

lowercase_words = word_tokenize(lowercase_text)
print(lowercase_words)
# Out:
# text mining, text data mining (tdm) or text analytics is the process of deriving high-quality information from text. it involves the discovery by computer of new, previously unknown information, by automatically extracting information from different written resources.[1] written resources may include websites, books, emails, reviews, and articles.[2] high-quality information is typically obtained by devising patterns and trends by means such as statistical pattern learning. according to hotho et al. (2005), there are three perspectives of text mining: information extraction, data mining, and knowledge discovery in databases (kdd).[3] text mining usually involves the process of structuring the input text (usually parsing, along with the addition of some derived linguistic features and the removal of others, and subsequent insertion into a database), deriving patterns within the structured data, and finally evaluation and interpretation of the output. 'high quality' in text mining usually refers to some combination of relevance, novelty, and interest. typical text mining tasks include text categorization, text clustering, concept/entity extraction, production of granular taxonomies, sentiment analysis, document summarization, and entity relation modeling (i.e., learning relations between named entities).
# ['text', 'mining', ',', 'text', 'data', 'mining', '(', 'tdm', ')', 'or', 'text', 'analytics', 'is', 'the', 'process', 'of', 'deriving', 'high-quality', 'information', 'from', 'text', '.', 'it', 'involves', 'the', 'discovery', 'by', 'computer', 'of', 'new', ',', 'previously', 'unknown', 'information', ',', 'by', 'automatically', 'extracting', 'information', 'from', 'different', 'written', 'resources', '.', '[', '1', ']', 'written', 'resources', 'may', 'include', 'websites', ',', 'books', ',', 'emails', ',', 'reviews', ',', 'and', 'articles', '.', '[', '2', ']', 'high-quality', 'information', 'is', 'typically', 'obtained', 'by', 'devising', 'patterns', 'and', 'trends', 'by', 'means', 'such', 'as', 'statistical', 'pattern', 'learning', '.', 'according', 'to', 'hotho', 'et', 'al', '.', '(', '2005', ')', ',', 'there', 'are', 'three', 'perspectives', 'of', 'text', 'mining', ':', 'information', 'extraction', ',', 'data', 'mining', ',', 'and', 'knowledge', 'discovery', 'in', 'databases', '(', 'kdd', ')', '.', '[', '3', ']', 'text', 'mining', 'usually', 'involves', 'the', 'process', 'of', 'structuring', 'the', 'input', 'text', '(', 'usually', 'parsing', ',', 'along', 'with', 'the', 'addition', 'of', 'some', 'derived', 'linguistic', 'features', 'and', 'the', 'removal', 'of', 'others', ',', 'and', 'subsequent', 'insertion', 'into', 'a', 'database', ')', ',', 'deriving', 'patterns', 'within', 'the', 'structured', 'data', ',', 'and', 'finally', 'evaluation', 'and', 'interpretation', 'of', 'the', 'output', '.', "'high", 'quality', "'", 'in', 'text', 'mining', 'usually', 'refers', 'to', 'some', 'combination', 'of', 'relevance', ',', 'novelty', ',', 'and', 'interest', '.', 'typical', 'text', 'mining', 'tasks', 'include', 'text', 'categorization', ',', 'text', 'clustering', ',', 'concept/entity', 'extraction', ',', 'production', 'of', 'granular', 'taxonomies', ',', 'sentiment', 'analysis', ',', 'document', 'summarization', ',', 'and', 'entity', 'relation', 'modeling', '(', 'i.e.', ',', 'learning', 'relations', 'between', 'named', 'entities', ')', '.']

# %% [markdown]
# #### Part-of-speech Tagging

# %%
from nltk import pos_tag

pos_tags = pos_tag(lowercase_words)
print(pos_tags)
# Out:
# [('text', 'NN'), ('mining', 'NN'), (',', ','), ('text', 'NN'), ('data', 'NNS'), ('mining', 'NN'), ('(', '('), ('tdm', 'NN'), (')', ')'), ('or', 'CC'), ('text', 'JJ'), ('analytics', 'NNS'), ('is', 'VBZ'), ('the', 'DT'), ('process', 'NN'), ('of', 'IN'), ('deriving', 'VBG'), ('high-quality', 'JJ'), ('information', 'NN'), ('from', 'IN'), ('text', 'NN'), ('.', '.'), ('it', 'PRP'), ('involves', 'VBZ'), ('the', 'DT'), ('discovery', 'NN'), ('by', 'IN'), ('computer', 'NN'), ('of', 'IN'), ('new', 'JJ'), (',', ','), ('previously', 'RB'), ('unknown', 'JJ'), ('information', 'NN'), (',', ','), ('by', 'IN'), ('automatically', 'RB'), ('extracting', 'VBG'), ('information', 'NN'), ('from', 'IN'), ('different', 'JJ'), ('written', 'VBN'), ('resources', 'NNS'), ('.', '.'), ('[', 'VB'), ('1', 'CD'), (']', 'NNP'), ('written', 'VBN'), ('resources', 'NNS'), ('may', 'MD'), ('include', 'VB'), ('websites', 'NNS'), (',', ','), ('books', 'NNS'), (',', ','), ('emails', 'NNS'), (',', ','), ('reviews', 'NNS'), (',', ','), ('and', 'CC'), ('articles', 'NNS'), ('.', '.'), ('[', '$'), ('2', 'CD'), (']', 'NNP'), ('high-quality', 'NN'), ('information', 'NN'), ('is', 'VBZ'), ('typically', 'RB'), ('obtained', 'VBN'), ('by', 'IN'), ('devising', 'VBG'), ('patterns', 'NNS'), ('and', 'CC'), ('trends', 'NNS'), ('by', 'IN'), ('means', 'NNS'), ('such', 'JJ'), ('as', 'IN'), ('statistical', 'JJ'), ('pattern', 'NN'), ('learning', 'NN'), ('.', '.'), ('according', 'VBG'), ('to', 'TO'), ('hotho', 'VB'), ('et', 'JJ'), ('al', 'NN'), ('.', '.'), ('(', '('), ('2005', 'CD'), (')', ')'), (',', ','), ('there', 'EX'), ('are', 'VBP'), ('three', 'CD'), ('perspectives', 'NNS'), ('of', 'IN'), ('text', 'NN'), ('mining', 'NN'), (':', ':'), ('information', 'NN'), ('extraction', 'NN'), (',', ','), ('data', 'NN'), ('mining', 'NN'), (',', ','), ('and', 'CC'), ('knowledge', 'VB'), ('discovery', 'NN'), ('in', 'IN'), ('databases', 'NNS'), ('(', '('), ('kdd', 'NN'), (')', ')'), ('.', '.'), ('[', '$'), ('3', 'CD'), (']', 'NNP'), ('text', 'NN'), ('mining', 'NN'), ('usually', 'RB'), ('involves', 'VBZ'), ('the', 'DT'), ('process', 'NN'), ('of', 'IN'), ('structuring', 'VBG'), ('the', 'DT'), ('input', 'NN'), ('text', 'NN'), ('(', '('), ('usually', 'RB'), ('parsing', 'VBG'), (',', ','), ('along', 'IN'), ('with', 'IN'), ('the', 'DT'), ('addition', 'NN'), ('of', 'IN'), ('some', 'DT'), ('derived', 'VBN'), ('linguistic', 'JJ'), ('features', 'NNS'), ('and', 'CC'), ('the', 'DT'), ('removal', 'NN'), ('of', 'IN'), ('others', 'NNS'), (',', ','), ('and', 'CC'), ('subsequent', 'JJ'), ('insertion', 'NN'), ('into', 'IN'), ('a', 'DT'), ('database', 'NN'), (')', ')'), (',', ','), ('deriving', 'VBG'), ('patterns', 'NNS'), ('within', 'IN'), ('the', 'DT'), ('structured', 'JJ'), ('data', 'NNS'), (',', ','), ('and', 'CC'), ('finally', 'RB'), ('evaluation', 'NN'), ('and', 'CC'), ('interpretation', 'NN'), ('of', 'IN'), ('the', 'DT'), ('output', 'NN'), ('.', '.'), ("'high", 'JJ'), ('quality', 'NN'), ("'", "''"), ('in', 'IN'), ('text', 'JJ'), ('mining', 'NN'), ('usually', 'RB'), ('refers', 'VBZ'), ('to', 'TO'), ('some', 'DT'), ('combination', 'NN'), ('of', 'IN'), ('relevance', 'NN'), (',', ','), ('novelty', 'NN'), (',', ','), ('and', 'CC'), ('interest', 'NN'), ('.', '.'), ('typical', 'JJ'), ('text', 'NN'), ('mining', 'NN'), ('tasks', 'NNS'), ('include', 'VBP'), ('text', 'JJ'), ('categorization', 'NN'), (',', ','), ('text', 'NN'), ('clustering', 'NN'), (',', ','), ('concept/entity', 'NN'), ('extraction', 'NN'), (',', ','), ('production', 'NN'), ('of', 'IN'), ('granular', 'JJ'), ('taxonomies', 'NNS'), (',', ','), ('sentiment', 'NN'), ('analysis', 'NN'), (',', ','), ('document', 'NN'), ('summarization', 'NN'), (',', ','), ('and', 'CC'), ('entity', 'NN'), ('relation', 'NN'), ('modeling', 'NN'), ('(', '('), ('i.e.', 'FW'), (',', ','), ('learning', 'VBG'), ('relations', 'NNS'), ('between', 'IN'), ('named', 'VBN'), ('entities', 'NNS'), (')', ')'), ('.', '.')]

# %% [markdown]
# #### Remove Stop Words

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')

stop_words = set(stopwords.words('english'))
filtered_sentence = [word for word in nltk_words if word not in stop_words]
print(filtered_sentence)
# Out:
# ['Text', 'mining', ',', 'text', 'data', 'mining', '(', 'TDM', ')', 'text', 'analytics', 'process', 'deriving', 'high-quality', 'information', 'text', '.', 'It', 'involves', 'discovery', 'computer', 'new', ',', 'previously', 'unknown', 'information', ',', 'automatically', 'extracting', 'information', 'different', 'written', 'resources', '.', '[', '1', ']', 'Written', 'resources', 'may', 'include', 'websites', ',', 'books', ',', 'emails', ',', 'reviews', ',', 'articles', '.', '[', '2', ']', 'High-quality', 'information', 'typically', 'obtained', 'devising', 'patterns', 'trends', 'means', 'statistical', 'pattern', 'learning', '.', 'According', 'Hotho', 'et', 'al', '.', '(', '2005', ')', ',', 'three', 'perspectives', 'text', 'mining', ':', 'information', 'extraction', ',', 'data', 'mining', ',', 'knowledge', 'discovery', 'databases', '(', 'KDD', ')', '.', '[', '3', ']', 'Text', 'mining', 'usually', 'involves', 'process', 'structuring', 'input', 'text', '(', 'usually', 'parsing', ',', 'along', 'addition', 'derived', 'linguistic', 'features', 'removal', 'others', ',', 'subsequent', 'insertion', 'database', ')', ',', 'deriving', 'patterns', 'within', 'structured', 'data', ',', 'finally', 'evaluation', 'interpretation', 'output', '.', "'High", 'quality', "'", 'text', 'mining', 'usually', 'refers', 'combination', 'relevance', ',', 'novelty', ',', 'interest', '.', 'Typical', 'text', 'mining', 'tasks', 'include', 'text', 'categorization', ',', 'text', 'clustering', ',', 'concept/entity', 'extraction', ',', 'production', 'granular', 'taxonomies', ',', 'sentiment', 'analysis', ',', 'document', 'summarization', ',', 'entity', 'relation', 'modeling', '(', 'i.e.', ',', 'learning', 'relations', 'named', 'entities', ')', '.']
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/mjiang228/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# #### Stemming

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in filtered_sentence]
print(stemmed_words)
# Out:
# ['text', 'mine', ',', 'text', 'data', 'mine', '(', 'tdm', ')', 'text', 'analyt', 'process', 'deriv', 'high-qual', 'inform', 'text', '.', 'it', 'involv', 'discoveri', 'comput', 'new', ',', 'previous', 'unknown', 'inform', ',', 'automat', 'extract', 'inform', 'differ', 'written', 'resourc', '.', '[', '1', ']', 'written', 'resourc', 'may', 'includ', 'websit', ',', 'book', ',', 'email', ',', 'review', ',', 'articl', '.', '[', '2', ']', 'high-qual', 'inform', 'typic', 'obtain', 'devis', 'pattern', 'trend', 'mean', 'statist', 'pattern', 'learn', '.', 'accord', 'hotho', 'et', 'al', '.', '(', '2005', ')', ',', 'three', 'perspect', 'text', 'mine', ':', 'inform', 'extract', ',', 'data', 'mine', ',', 'knowledg', 'discoveri', 'databas', '(', 'kdd', ')', '.', '[', '3', ']', 'text', 'mine', 'usual', 'involv', 'process', 'structur', 'input', 'text', '(', 'usual', 'pars', ',', 'along', 'addit', 'deriv', 'linguist', 'featur', 'remov', 'other', ',', 'subsequ', 'insert', 'databas', ')', ',', 'deriv', 'pattern', 'within', 'structur', 'data', ',', 'final', 'evalu', 'interpret', 'output', '.', "'high", 'qualiti', "'", 'text', 'mine', 'usual', 'refer', 'combin', 'relev', ',', 'novelti', ',', 'interest', '.', 'typic', 'text', 'mine', 'task', 'includ', 'text', 'categor', ',', 'text', 'cluster', ',', 'concept/ent', 'extract', ',', 'product', 'granular', 'taxonomi', ',', 'sentiment', 'analysi', ',', 'document', 'summar', ',', 'entiti', 'relat', 'model', '(', 'i.e.', ',', 'learn', 'relat', 'name', 'entiti', ')', '.']

# %% [markdown]
# #### Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in stemmed_words]
print(lemmatized_words)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/mjiang228/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ['text', 'mine', ',', 'text', 'data', 'mine', '(', 'tdm', ')', 'text', 'analyt', 'process', 'deriv', 'high-qual', 'inform', 'text', '.', 'it', 'involv', 'discoveri', 'comput', 'new', ',', 'previous', 'unknown', 'inform', ',', 'automat', 'extract', 'inform', 'differ', 'written', 'resourc', '.', '[', '1', ']', 'written', 'resourc', 'may', 'includ', 'websit', ',', 'book', ',', 'email', ',', 'review', ',', 'articl', '.', '[', '2', ']', 'high-qual', 'inform', 'typic', 'obtain', 'devi', 'pattern', 'trend', 'mean', 'statist', 'pattern', 'learn', '.', 'accord', 'hotho', 'et', 'al', '.', '(', '2005', ')', ',', 'three', 'perspect', 'text', 'mine', ':', 'inform', 'extract', ',', 'data', 'mine', ',', 'knowledg', 'discoveri', 'databas', '(', 'kdd', ')', '.', '[', '3', ']', 'text', 'mine', 'usual', 'involv', 'process', 'structur', 'input', 'text', '(', 'usual', 'par', ',', 'along', 'addit', 'deriv', 'linguist', 'featur', 'remov', 'other', ',', 'subsequ', 'insert', 'databas', ')', ',', 'deriv', 'pattern', 'within', 'structur', 'data', ',', 'final', 'evalu', 'interpret', 'output', '.', "'high", 'qualiti', "'", 'text', 'mine', 'usual', 'refer', 'combin', 'relev', ',', 'novelti', ',', 'interest', '.', 'typic', 'text', 'mine', 'task', 'includ', 'text', 'categor', ',', 'text', 'cluster', ',', 'concept/ent', 'extract', ',', 'product', 'granular', 'taxonomi', ',', 'sentiment', 'analysi', ',', 'document', 'summar', ',', 'entiti', 'relat', 'model', '(', 'i.e.', ',', 'learn', 'relat', 'name', 'entiti', ')', '.']

# %% [markdown]
# ## Use Spacy for Text Preprocessing
#
# #### Sentence Segmentation

# %%
doc = nlp(text)

spacy_sentences = list(doc.sents)
print("Number of sentences: ", len(spacy_sentences))
print("\n")

for s in spacy_sentences:
    print (s)
# Out:
# Number of sentences:  5
#
#
# Text mining, text data mining (TDM) or text analytics is the process of deriving high-quality information from text.
# It involves the discovery by computer of new, previously unknown information, by automatically extracting information from different written resources.[1] Written resources may include websites, books, emails, reviews, and articles.[2] High-quality information is typically obtained by devising patterns and trends by means such as statistical pattern learning.
# According to Hotho et al. (2005), there are three perspectives of text mining: information extraction, data mining, and knowledge discovery in databases (KDD).[3] Text mining usually involves the process of structuring the input text (usually parsing, along with the addition of some derived linguistic features and the removal of others, and subsequent insertion into a database), deriving patterns within the structured data, and finally evaluation and interpretation of the output.
# 'High quality' in text mining usually refers to some combination of relevance, novelty, and interest.
# Typical text mining tasks include text categorization, text clustering, concept/entity extraction, production of granular taxonomies, sentiment analysis, document summarization, and entity relation modeling (i.e., learning relations between named entities).

# %% [markdown]
# #### Tokenization

# %%
spacy_tokens = list(doc)
print(spacy_tokens)
# Out:
# [Text, mining, ,, text, data, mining, (, TDM, ), or, text, analytics, is, the, process, of, deriving, high, -, quality, information, from, text, ., It, involves, the, discovery, by, computer, of, new, ,, previously, unknown, information, ,, by, automatically, extracting, information, from, different, written, resources.[1, ], Written, resources, may, include, websites, ,, books, ,, emails, ,, reviews, ,, and, articles.[2, ], High, -, quality, information, is, typically, obtained, by, devising, patterns, and, trends, by, means, such, as, statistical, pattern, learning, ., According, to, Hotho, et, al, ., (, 2005, ), ,, there, are, three, perspectives, of, text, mining, :, information, extraction, ,, data, mining, ,, and, knowledge, discovery, in, databases, (, KDD).[3, ], Text, mining, usually, involves, the, process, of, structuring, the, input, text, (, usually, parsing, ,, along, with, the, addition, of, some, derived, linguistic, features, and, the, removal, of, others, ,, and, subsequent, insertion, into, a, database, ), ,, deriving, patterns, within, the, structured, data, ,, and, finally, evaluation, and, interpretation, of, the, output, ., ', High, quality, ', in, text, mining, usually, refers, to, some, combination, of, relevance, ,, novelty, ,, and, interest, ., Typical, text, mining, tasks, include, text, categorization, ,, text, clustering, ,, concept, /, entity, extraction, ,, production, of, granular, taxonomies, ,, sentiment, analysis, ,, document, summarization, ,, and, entity, relation, modeling, (, i.e., ,, learning, relations, between, named, entities, ), .]

# %% [markdown]
# #### Case Normalization

# %%
lowercase_text = text.lower()
print(lowercase_text)

lowercase_doc = nlp(lowercase_text)
lowercase_tokens = list(lowercase_doc)
print(lowercase_tokens)
# Out:
# text mining, text data mining (tdm) or text analytics is the process of deriving high-quality information from text. it involves the discovery by computer of new, previously unknown information, by automatically extracting information from different written resources.[1] written resources may include websites, books, emails, reviews, and articles.[2] high-quality information is typically obtained by devising patterns and trends by means such as statistical pattern learning. according to hotho et al. (2005), there are three perspectives of text mining: information extraction, data mining, and knowledge discovery in databases (kdd).[3] text mining usually involves the process of structuring the input text (usually parsing, along with the addition of some derived linguistic features and the removal of others, and subsequent insertion into a database), deriving patterns within the structured data, and finally evaluation and interpretation of the output. 'high quality' in text mining usually refers to some combination of relevance, novelty, and interest. typical text mining tasks include text categorization, text clustering, concept/entity extraction, production of granular taxonomies, sentiment analysis, document summarization, and entity relation modeling (i.e., learning relations between named entities).
# [text, mining, ,, text, data, mining, (, tdm, ), or, text, analytics, is, the, process, of, deriving, high, -, quality, information, from, text, ., it, involves, the, discovery, by, computer, of, new, ,, previously, unknown, information, ,, by, automatically, extracting, information, from, different, written, resources.[1, ], written, resources, may, include, websites, ,, books, ,, emails, ,, reviews, ,, and, articles.[2, ], high, -, quality, information, is, typically, obtained, by, devising, patterns, and, trends, by, means, such, as, statistical, pattern, learning, ., according, to, hotho, et, al, ., (, 2005, ), ,, there, are, three, perspectives, of, text, mining, :, information, extraction, ,, data, mining, ,, and, knowledge, discovery, in, databases, (, kdd).[3, ], text, mining, usually, involves, the, process, of, structuring, the, input, text, (, usually, parsing, ,, along, with, the, addition, of, some, derived, linguistic, features, and, the, removal, of, others, ,, and, subsequent, insertion, into, a, database, ), ,, deriving, patterns, within, the, structured, data, ,, and, finally, evaluation, and, interpretation, of, the, output, ., ', high, quality, ', in, text, mining, usually, refers, to, some, combination, of, relevance, ,, novelty, ,, and, interest, ., typical, text, mining, tasks, include, text, categorization, ,, text, clustering, ,, concept, /, entity, extraction, ,, production, of, granular, taxonomies, ,, sentiment, analysis, ,, document, summarization, ,, and, entity, relation, modeling, (, i.e., ,, learning, relations, between, named, entities, ), .]

# %% [markdown]
# #### Part-of-speech Tagging

# %%
for token in lowercase_doc:
    print(f"{token.text} {token.pos_} {token.tag_}")
# Out:
# text NOUN NN
# mining NOUN NN
# , PUNCT ,
# text NOUN NN
# data NOUN NNS
# mining NOUN NN
# ( PUNCT -LRB-
# tdm PROPN NNP
# ) PUNCT -RRB-
# or CCONJ CC
# text NOUN NN
# analytics NOUN NNS
# is AUX VBZ
# the DET DT
# process NOUN NN
# of ADP IN
# deriving VERB VBG
# high ADJ JJ
# - PUNCT HYPH
# quality NOUN NN
# information NOUN NN
# from ADP IN
# text NOUN NN
# . PUNCT .
# it PRON PRP
# involves VERB VBZ
# the DET DT
# discovery NOUN NN
# by ADP IN
# computer NOUN NN
# of ADP IN
# new ADJ JJ
# , PUNCT ,
# previously ADV RB
# unknown ADJ JJ
# information NOUN NN
# , PUNCT ,
# by ADP IN
# automatically ADV RB
# extracting VERB VBG
# information NOUN NN
# from ADP IN
# different ADJ JJ
# written VERB VBN
# resources.[1 NOUN NN
# ] PUNCT -RRB-
# written VERB VBN
# resources NOUN NNS
# may AUX MD
# include VERB VB
# websites NOUN NNS
# , PUNCT ,
# books NOUN NNS
# , PUNCT ,
# emails NOUN NNS
# , PUNCT ,
# reviews NOUN NNS
# , PUNCT ,
# and CCONJ CC
# articles.[2 X FW
# ] X XX
# high ADJ JJ
# - PUNCT HYPH
# quality NOUN NN
# information NOUN NN
# is AUX VBZ
# typically ADV RB
# obtained VERB VBN
# by ADP IN
# devising VERB VBG
# patterns NOUN NNS
# and CCONJ CC
# trends NOUN NNS
# by ADP IN
# means NOUN NNS
# such ADJ JJ
# as ADP IN
# statistical ADJ JJ
# pattern NOUN NN
# learning VERB VBG
# . PUNCT .
# according VERB VBG
# to ADP IN
# hotho PROPN NNP
# et PROPN NNP
# al PROPN NNP
# . PUNCT .
# ( PUNCT -LRB-
# 2005 NUM CD
# ) PUNCT -RRB-
# , PUNCT ,
# there PRON EX
# are VERB VBP
# three NUM CD
# perspectives NOUN NNS
# of ADP IN
# text NOUN NN
# mining NOUN NN
# : PUNCT :
# information NOUN NN
# extraction NOUN NN
# , PUNCT ,
# data NOUN NNS
# mining NOUN NN
# , PUNCT ,
# and CCONJ CC
# knowledge NOUN NN
# discovery NOUN NN
# in ADP IN
# databases NOUN NNS
# ( PUNCT -LRB-
# kdd).[3 PROPN NNP
# ] X XX
# text NOUN NN
# mining NOUN NN
# usually ADV RB
# involves VERB VBZ
# the DET DT
# process NOUN NN
# of ADP IN
# structuring VERB VBG
# the DET DT
# input NOUN NN
# text NOUN NN
# ( PUNCT -LRB-
# usually ADV RB
# parsing VERB VBG
# , PUNCT ,
# along ADP IN
# with ADP IN
# the DET DT
# addition NOUN NN
# of ADP IN
# some DET DT
# derived VERB VBN
# linguistic ADJ JJ
# features NOUN NNS
# and CCONJ CC
# the DET DT
# removal NOUN NN
# of ADP IN
# others NOUN NNS
# , PUNCT ,
# and CCONJ CC
# subsequent ADJ JJ
# insertion NOUN NN
# into ADP IN
# a DET DT
# database NOUN NN
# ) PUNCT -RRB-
# , PUNCT ,
# deriving VERB VBG
# patterns NOUN NNS
# within ADP IN
# the DET DT
# structured ADJ JJ
# data NOUN NNS
# , PUNCT ,
# and CCONJ CC
# finally ADV RB
# evaluation NOUN NN
# and CCONJ CC
# interpretation NOUN NN
# of ADP IN
# the DET DT
# output NOUN NN
# . PUNCT .
# ' PUNCT ``
# high ADJ JJ
# quality NOUN NN
# ' PUNCT ''
# in ADP IN
# text NOUN NN
# mining NOUN NN
# usually ADV RB
# refers VERB VBZ
# to ADP IN
# some DET DT
# combination NOUN NN
# of ADP IN
# relevance NOUN NN
# , PUNCT ,
# novelty NOUN NN
# , PUNCT ,
# and CCONJ CC
# interest NOUN NN
# . PUNCT .
# typical ADJ JJ
# text NOUN NN
# mining NOUN NN
# tasks NOUN NNS
# include VERB VBP
# text NOUN NN
# categorization NOUN NN
# , PUNCT ,
# text NOUN NN
# clustering NOUN NN
# , PUNCT ,
# concept NOUN NN
# / SYM SYM
# entity NOUN NN
# extraction NOUN NN
# , PUNCT ,
# production NOUN NN
# of ADP IN
# granular ADJ JJ
# taxonomies NOUN NNS
# , PUNCT ,
# sentiment NOUN NN
# analysis NOUN NN
# , PUNCT ,
# document NOUN NN
# summarization NOUN NN
# , PUNCT ,
# and CCONJ CC
# entity NOUN NN
# relation NOUN NN
# modeling NOUN NN
# ( PUNCT -LRB-
# i.e. X FW
# , PUNCT ,
# learning VERB VBG
# relations NOUN NNS
# between ADP IN
# named VERB VBN
# entities NOUN NNS
# ) PUNCT -RRB-
# . PUNCT .

# %% [markdown]
# #### Remove Stop Words

# %%
filtered_tokens = [token.text for token in lowercase_doc if not token.is_stop and not token.is_punct and not token.is_space]
print(filtered_tokens)
# Out:
# ['text', 'mining', 'text', 'data', 'mining', 'tdm', 'text', 'analytics', 'process', 'deriving', 'high', 'quality', 'information', 'text', 'involves', 'discovery', 'computer', 'new', 'previously', 'unknown', 'information', 'automatically', 'extracting', 'information', 'different', 'written', 'resources.[1', 'written', 'resources', 'include', 'websites', 'books', 'emails', 'reviews', 'articles.[2', 'high', 'quality', 'information', 'typically', 'obtained', 'devising', 'patterns', 'trends', 'means', 'statistical', 'pattern', 'learning', 'according', 'hotho', 'et', 'al', '2005', 'perspectives', 'text', 'mining', 'information', 'extraction', 'data', 'mining', 'knowledge', 'discovery', 'databases', 'kdd).[3', 'text', 'mining', 'usually', 'involves', 'process', 'structuring', 'input', 'text', 'usually', 'parsing', 'addition', 'derived', 'linguistic', 'features', 'removal', 'subsequent', 'insertion', 'database', 'deriving', 'patterns', 'structured', 'data', 'finally', 'evaluation', 'interpretation', 'output', 'high', 'quality', 'text', 'mining', 'usually', 'refers', 'combination', 'relevance', 'novelty', 'interest', 'typical', 'text', 'mining', 'tasks', 'include', 'text', 'categorization', 'text', 'clustering', 'concept', 'entity', 'extraction', 'production', 'granular', 'taxonomies', 'sentiment', 'analysis', 'document', 'summarization', 'entity', 'relation', 'modeling', 'i.e.', 'learning', 'relations', 'named', 'entities']

# %% [markdown]
# #### Stemming
#
# Spacy does not have a built-in Porter stemmer or any other traditional stemming function because it relies exclusively on lemmatization.

# %% [markdown]
# #### Lemmatization

# %%
for token in lowercase_doc:
    if not token.is_stop and not token.is_punct and not token.is_space:
        print(f"Token: {token.text}, Lemma: {token.lemma_}")
# Out:
# Token: text, Lemma: text
# Token: mining, Lemma: mining
# Token: text, Lemma: text
# Token: data, Lemma: datum
# Token: mining, Lemma: mining
# Token: tdm, Lemma: tdm
# Token: text, Lemma: text
# Token: analytics, Lemma: analytic
# Token: process, Lemma: process
# Token: deriving, Lemma: derive
# Token: high, Lemma: high
# Token: quality, Lemma: quality
# Token: information, Lemma: information
# Token: text, Lemma: text
# Token: involves, Lemma: involve
# Token: discovery, Lemma: discovery
# Token: computer, Lemma: computer
# Token: new, Lemma: new
# Token: previously, Lemma: previously
# Token: unknown, Lemma: unknown
# Token: information, Lemma: information
# Token: automatically, Lemma: automatically
# Token: extracting, Lemma: extract
# Token: information, Lemma: information
# Token: different, Lemma: different
# Token: written, Lemma: write
# Token: resources.[1, Lemma: resources.[1
# Token: written, Lemma: write
# Token: resources, Lemma: resource
# Token: include, Lemma: include
# Token: websites, Lemma: website
# Token: books, Lemma: book
# Token: emails, Lemma: email
# Token: reviews, Lemma: review
# Token: articles.[2, Lemma: articles.[2
# Token: high, Lemma: high
# Token: quality, Lemma: quality
# Token: information, Lemma: information
# Token: typically, Lemma: typically
# Token: obtained, Lemma: obtain
# Token: devising, Lemma: devise
# Token: patterns, Lemma: pattern
# Token: trends, Lemma: trend
# Token: means, Lemma: mean
# Token: statistical, Lemma: statistical
# Token: pattern, Lemma: pattern
# Token: learning, Lemma: learn
# Token: according, Lemma: accord
# Token: hotho, Lemma: hotho
# Token: et, Lemma: et
# Token: al, Lemma: al
# Token: 2005, Lemma: 2005
# Token: perspectives, Lemma: perspective
# Token: text, Lemma: text
# Token: mining, Lemma: mining
# Token: information, Lemma: information
# Token: extraction, Lemma: extraction
# Token: data, Lemma: datum
# Token: mining, Lemma: mining
# Token: knowledge, Lemma: knowledge
# Token: discovery, Lemma: discovery
# Token: databases, Lemma: database
# Token: kdd).[3, Lemma: kdd).[3
# Token: text, Lemma: text
# Token: mining, Lemma: mining
# Token: usually, Lemma: usually
# Token: involves, Lemma: involve
# Token: process, Lemma: process
# Token: structuring, Lemma: structure
# Token: input, Lemma: input
# Token: text, Lemma: text
# Token: usually, Lemma: usually
# Token: parsing, Lemma: parse
# Token: addition, Lemma: addition
# Token: derived, Lemma: derive
# Token: linguistic, Lemma: linguistic
# Token: features, Lemma: feature
# Token: removal, Lemma: removal
# Token: subsequent, Lemma: subsequent
# Token: insertion, Lemma: insertion
# Token: database, Lemma: database
# Token: deriving, Lemma: derive
# Token: patterns, Lemma: pattern
# Token: structured, Lemma: structured
# Token: data, Lemma: datum
# Token: finally, Lemma: finally
# Token: evaluation, Lemma: evaluation
# Token: interpretation, Lemma: interpretation
# Token: output, Lemma: output
# Token: high, Lemma: high
# Token: quality, Lemma: quality
# Token: text, Lemma: text
# Token: mining, Lemma: mining
# Token: usually, Lemma: usually
# Token: refers, Lemma: refer
# Token: combination, Lemma: combination
# Token: relevance, Lemma: relevance
# Token: novelty, Lemma: novelty
# Token: interest, Lemma: interest
# Token: typical, Lemma: typical
# Token: text, Lemma: text
# Token: mining, Lemma: mining
# Token: tasks, Lemma: task
# Token: include, Lemma: include
# Token: text, Lemma: text
# Token: categorization, Lemma: categorization
# Token: text, Lemma: text
# Token: clustering, Lemma: clustering
# Token: concept, Lemma: concept
# Token: entity, Lemma: entity
# Token: extraction, Lemma: extraction
# Token: production, Lemma: production
# Token: granular, Lemma: granular
# Token: taxonomies, Lemma: taxonomy
# Token: sentiment, Lemma: sentiment
# Token: analysis, Lemma: analysis
# Token: document, Lemma: document
# Token: summarization, Lemma: summarization
# Token: entity, Lemma: entity
# Token: relation, Lemma: relation
# Token: modeling, Lemma: modeling
# Token: i.e., Lemma: i.e.
# Token: learning, Lemma: learn
# Token: relations, Lemma: relation
# Token: named, Lemma: name
# Token: entities, Lemma: entity

# %% [markdown]
# ## Questions
#
# Compare the text preprocessing results of NLTK and spaCy. What are the pros and cons of each?

# %% [markdown]
# ## In-class Exercise
# * Counting the most frequent nouns (NN, NNP, NNS, or NNPS) in the provided text.

# %%
raw = 'BAHIA COCOA REVIEW  Showers continued throughout the week in  the Bahia cocoa zone, alleviating the drought since early  January and improving prospects for the coming temporao,  although normal humidity levels have not been restored,  Comissaria Smith said in its weekly review.      The dry period means the temporao will be late this year.      Arrivals for the week ended February 22 were 155,221 bags  of 60 kilos making a cumulative total for the season of 5.93  mln against 5.81 at the same stage last year. Again it seems  that cocoa delivered earlier on consignment was included in the  arrivals figures.      Comissaria Smith said there is still some doubt as to how  much old crop cocoa is still available as harvesting has  practically come to an end. With total Bahia crop estimates  around 6.4 mln bags and sales standing at almost 6.2 mln there  are a few hundred thousand bags still in the hands of farmers,  middlemen, exporters and processors.      There are doubts as to how much of this cocoa would be fit  for export as shippers are now experiencing dificulties in  obtaining +Bahia superior+ certificates.      In view of the lower quality over recent weeks farmers have  sold a good part of their cocoa held on consignment.      Comissaria Smith said spot bean prices rose to 340 to 350  cruzados per arroba of 15 kilos.      Bean shippers were reluctant to offer nearby shipment and  only limited sales were booked for March shipment at 1,750 to  1,780 dlrs per tonne to ports to be named.      New crop sales were also light and all to open ports with  June/July going at 1,850 and 1,880 dlrs and at 35 and 45 dlrs  under New York july, Aug/Sept at 1,870, 1,875 and 1,880 dlrs  per tonne FOB.      Routine sales of butter were made. March/April sold at  4,340, 4,345 and 4,350 dlrs.      April/May butter went at 2.27 times New York May, June/July  at 4,400 and 4,415 dlrs, Aug/Sept at 4,351 to 4,450 dlrs and at  2.27 and 2.28 times New York Sept and Oct/Dec at 4,480 dlrs and  2.27 times New York Dec, Comissaria Smith said.      Destinations were the U.S., Covertible currency areas,  Uruguay and open ports.      Cake sales were registered at 785 to 995 dlrs for  March/April, 785 dlrs for May, 753 dlrs for Aug and 0.39 times  New York Dec for Oct/Dec.      Buyers were the U.S., Argentina, Uruguay and convertible  currency areas.      Liquor sales were limited with March/April selling at 2,325  and 2,380 dlrs, June/July at 2,375 dlrs and at 1.25 times New  York July, Aug/Sept at 2,400 dlrs and at 1.25 times New York  Sept and Oct/Dec at 1.25 times New York Dec, Comissaria Smith  said.      Total Bahia sales are currently estimated at 6.13 mln bags  against the 1986/87 crop and 1.06 mln bags against the 1987/88  crop.      Final figures for the period to February 28 are expected to  be published by the Brazilian Cocoa Trade Commission after  carnival which ends midday on February 27.'

text = nlp(raw)

# %%
from collections import Counter

# write a list comprehension [] for all tokens' lemma
# use Counter([ your list comprehension ]).most_common()

# %%
Counter( [ t.lower_ for t in text if t.tag_ in ['NN', 'NNP', 'NNS', 'NNPS'] ] ).most_common()
# Out:
# [('dlrs', 14),
#  ('new', 8),
#  ('york', 8),
#  ('cocoa', 7),
#  ('sales', 7),
#  ('times', 7),
#  ('comissaria', 5),
#  ('smith', 5),
#  ('bags', 5),
#  ('crop', 5),
#  ('july', 5),
#  ('sept', 5),
#  ('dec', 5),
#  ('march', 4),
#  ('aug', 4),
#  ('april', 4),
#  ('bahia', 3),
#  ('february', 3),
#  ('mln', 3),
#  ('ports', 3),
#  ('june', 3),
#  ('may', 3),
#  ('oct', 3),
#  ('review', 2),
#  ('week', 2),
#  ('temporao', 2),
#  ('period', 2),
#  ('year', 2),
#  ('arrivals', 2),
#  ('kilos', 2),
#  ('total', 2),
#  ('consignment', 2),
#  ('figures', 2),
#  ('farmers', 2),
#  ('shippers', 2),
#  ('bean', 2),
#  ('shipment', 2),
#  ('tonne', 2),
#  ('butter', 2),
#  ('u.s.', 2),
#  ('currency', 2),
#  ('areas', 2),
#  ('uruguay', 2),
#  ('showers', 1),
#  ('zone', 1),
#  ('drought', 1),
#  ('january', 1),
#  ('prospects', 1),
#  ('humidity', 1),
#  ('levels', 1),
#  ('season', 1),
#  ('stage', 1),
#  ('doubt', 1),
#  ('harvesting', 1),
#  ('end', 1),
#  ('hands', 1),
#  ('middlemen', 1),
#  ('exporters', 1),
#  ('processors', 1),
#  ('doubts', 1),
#  ('export', 1),
#  ('dificulties', 1),
#  ('obtaining', 1),
#  ('superior+', 1),
#  ('certificates', 1),
#  ('view', 1),
#  ('quality', 1),
#  ('weeks', 1),
#  ('part', 1),
#  ('spot', 1),
#  ('prices', 1),
#  ('cruzados', 1),
#  ('arroba', 1),
#  ('fob', 1),
#  ('destinations', 1),
#  ('cake', 1),
#  ('dec.', 1),
#  ('buyers', 1),
#  ('argentina', 1),
#  ('liquor', 1),
#  ('selling', 1),
#  ('brazilian', 1),
#  ('trade', 1),
#  ('commission', 1),
#  ('carnival', 1),
#  ('midday', 1)]
