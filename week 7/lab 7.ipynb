# %%
# !pip install transformers

# %%
# For BERT
from transformers import DistilBertTokenizerFast, DistilBertModel

# For data manipulation and analysis
import pandas as pd
pd.options.display.max_colwidth = 200
import numpy as np
from sklearn.decomposition import PCA

# For interactive data visualization
import altair as alt

# %%
url = "https://raw.githubusercontent.com/melaniewalsh/BERT-4-Humanists/main/data/public-domain-poetry.csv"

poetry_df = pd.read_csv(url, encoding='utf-8')
# Show 5 random rows
poetry_df.sample(5)
# Out:
#                     author                                        title  \
# 16562        Matthew Prior  Songs Set To Music: 11. Set By Mr. De Fesch
# 6959          Emma Lazarus                        The Banner Of The Jew
# 10468      Herman Melville        Lyon. Battle Of Springfield, Missouri
# 3492    Charles Baudelaire                                    The Clock
# 8552   George Gordon Byron                                      Mazeppa
#
#                                                                                                                                                                                                           text  \
# 16562  Morella, charming without art,\r\nAnd kind without design,\r\nCan never lose the smallest part\r\nOf such a heart as mine.\n\r\nObliged a thousand several ways,\r\nIt ne'er can break her chains,\r...
# 6959   Wake, Israel, wake! Recall to-day\r\nThe glorious Maccabean rage,\r\nThe sire heroic, hoary-gray,\r\nHis five-fold lion-lineage:\r\nThe Wise, the Elect, the Help-of-God,\r\nThe Burst-of-Spring, th...
# 10468   (August, 1861.)\n\n\r\n Some hearts there are of deeper sort,\r\n Prophetic, sad,\r\n Which yet for cause are trebly clad;\r\n Known death they fly on:\r\n This wizard-heart and heart-of-oak had ...
# 3492   The Clock! a sinister, impassive god\r\nWhose threatening finger says to us: 'Remember!\r\nSoon in your anguished heart, as in a target,\r\nQuivering shafts of Grief will plant themselves;\n\r\nVa...
# 8552   \tIntroduction To Mazeppa\n\nMazeppa, a legend of the Russian Ukraine, or frontier region, is based on the passage in Voltaire's Charles XII. prefixed as the "Advertisement" to the poem. Voltaire ...
#
#                                 lifespan  birth_year  death_year  \
# 16562   July 21, 1664-September 18, 1721      1664.0      1721.0
# 6959     July 22, 1849-November 19, 1887      1849.0      1887.0
# 10468  August 1, 1819-September 28, 1891      1819.0      1891.0
# 3492     April 9, 1821 - August 31, 1867      1821.0      1867.0
# 8552       22 January 1788-19 April 1824      1788.0      1824.0
#
#                                                                                               link  \
# 16562  http://public-domain-poetry.com/matthew-prior/songs-set-to-music-11-set-by-mr-de-fesch-2975
# 6959                          http://public-domain-poetry.com/emma-lazarus/banner-of-the-jew-23063
# 10468    http://public-domain-poetry.com/herman-melville/lyon-battle-of-springfield-missouri-38479
# 3492                                 http://public-domain-poetry.com/charles-baudelaire/clock-8997
# 8552                             http://public-domain-poetry.com/george-gordon-byron/mazeppa-10630
#
#                                    period
# 16562  16th-17th Centuries (Early Modern)
# 6959                         19th Century
# 10468                        19th Century
# 3492                         19th Century
# 8552                         19th Century

# %%
len(poetry_df)
# Out:
# 31080

# %% [markdown]
# In-class Practice: Exploratory data analysis <br>
# Let's check to see which authors show up the most in this dataset (e.g., top 20) to get a sense of its contours:

# %% [markdown]
# Let's check to see what time periods show up the most in this dataset to get a sense of its contours:
